# %%
import os
import sys
spark_name = os.environ.get('SPARK_HOME',None)
if not spark_name:
    raise ValueErrorError('spark环境没有配置好')
sys.path.insert(0,os.path.join(spark_name,'python'))
sys.path.insert(0,os.path.join(spark_name,'python/lib/py4j-0.10.4-src.zip'))
exec(open(os.path.join(spark_name,'python/pyspark/shell.py')).read())
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 3.0.0
#       /_/
#
# Using Python version 3.8.3 (default, Jun  1 2020 17:43:00)
# SparkSession available as 'spark'.

# %%
from pyspark.sql.types import StringType
from pyspark.sql.functions import udf
from pyspark.sql.types import DoubleType

# %%
lis = [f for f in range(1,7)]
print(type(lis))
vec = sc.parallelize(lis)
print(type(vec))
print(vec.collect())
print(vec.count())

# %%
peopleDF = spark.read.json(r"./data/output.json")

# %%
peopleDF.printSchema()
# Out:
# root
#  |-- comment: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- star: string (nullable = true)
#  |-- user_name: string (nullable = true)

# %%
peopleDF.count()
# Out:
# 401564

# %%
peopleDF.collect()
# Out:
# [Row(comment='null', name='william-larue-weller-bourbon-fall-2015', star='5.0', user_name='noahmjohnson'),
#  Row(comment="tremendous. silky smooth for a barrel-proof. while i don't love wheated bourbons, this one delivers.", name='william-larue-weller-bourbon-fall-2015', star='5.0', user_name='New-Harvest-Coffee-Spirit'),
#  Row(comment='Neat - very hot in fact hard to appreciate the initial flavor because the heat comes so quickly and hits you like a jackhammer.  I had to put some water in it to enjoy it 😳', name='william-larue-weller-bourbon-fall-2015', star='3.0', user_name='BrokenBridge'),
#  Row(comment='An amazing Whiskey, it needs some water and a cube to really bring out the full flavour with such a high ABV.', name='william-larue-weller-bourbon-fall-2015', star='5.0', user_name='Darwincat67'),
#  Row(comment='null', name='william-larue-weller-bourbon-fall-2015', star='5.0', user_name='Jason-Penberthy'),
# ...

# %%
peopleDF.show()
# Out:
# +--------------------+--------------------+----+--------------------+
# |             comment|                name|star|           user_name|
# +--------------------+--------------------+----+--------------------+
# |                null|william-larue-wel...| 5.0|        noahmjohnson|
# |tremendous. silky...|william-larue-wel...| 5.0|New-Harvest-Coffe...|
# |Neat - very hot i...|william-larue-wel...| 3.0|        BrokenBridge|
# |An amazing Whiske...|william-larue-wel...| 5.0|         Darwincat67|
# |                null|william-larue-wel...| 5.0|     Jason-Penberthy|
# |                null|william-larue-wel...| 3.0|         mrfishyfish|
# |                null|william-larue-wel...| 5.0|         Adalessa211|
# |                null|william-larue-wel...| 5.0|     Craft-Beer-Geek|
# |                null|william-larue-wel...| 5.0|     Sergio-R-Garcia|
# |                null|william-larue-wel...| 4.0|           quickwing|
# ...

# %%
peopleDF.createOrReplaceTempView("wine_name")

# %%
some_whiskey = spark.sql("SELECT * FROM wine_name WHERE star='null'")

# %%
some_whiskey.count()
# Out:
# 9496

# %%
peopleDF.createOrReplaceTempView("wine_name")
five_star = spark.sql("SELECT * FROM wine_name")

# %%
five_star.count()
# Out:
# 401564

# %%
import plotly

# %%
from pyspark.sql.types import *

# %%
schema = StructType([
    StructField("comment", StringType(), True),
    StructField("name", StringType(),True),
    StructField("star", IntegerType(),True),
    StructField("user_name", StringType(), True)
])

# %%
df = spark.read.csv(r"./data/output.csv", header=True, schema=schema)

# %%
df.show()
# Out:
# +--------------------+--------------------+----+------------------+
# |             comment|                name|star|         user_name|
# +--------------------+--------------------+----+------------------+
# |                null|thomas-h-handy-sa...|null|    DanielMeichtry|
# |                null|thomas-h-handy-sa...|null|        Coladaking|
# |                null|thomas-h-handy-sa...|null|        Al-Jameson|
# |                null|thomas-h-handy-sa...|null|           calowe2|
# |                null|thomas-h-handy-sa...|null|   Stephen-Philips|
# |                null|thomas-h-handy-sa...|null|   Craft-Beer-Geek|
# |                null|thomas-h-handy-sa...|null|            jj9096|
# |Believe the hype....|thomas-h-handy-sa...|null|        petermania|
# |     $80 - Michigan.|thomas-h-handy-sa...|null|           gvsufan|
# |Heard a lot about...|thomas-h-handy-sa...|null|           Joe-joe|
# |                null|port-ellen-32-yea...|null|         cvireak10|
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DF = df.select("*").toPandas()

# %%
DF.iloc[:,2].plot.bar()

# %%
dfPlot = five_star.select("star").groupBy("star").count()

# %%
dfPlot.show()
# Out:
# +----+------+
# |star| count|
# +----+------+
# | 1.0|  5696|
# |0.75|   193|
# |0.25|   319|
# |3.75| 25078|
# | 4.5| 22473|
# | 2.5|  5927|
# | 0.0|    38|
# | 3.5| 25380|
# |1.75|   798|
# | 5.0| 54393|
# | 0.5|   376|
# |1.25|   322|
# | 4.0|115963|
# |3.25| 12128|
# |4.75|  7440|
# | 1.5|  1106|
# | 2.0| 18241|
# |2.75|  5005|
# |4.25| 24334|
# | 3.0| 64889|
# +----+------+
# only showing top 20 rows

# %%
x= dfPlot.toPandas()['star'].values.tolist()
y= dfPlot.toPandas()['count'].values.tolist()

# %%
plt.bar(x,y)
plt.show()
